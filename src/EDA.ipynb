# %%
import cv2
import numpy as np

# %%
img  = cv2.imread(r"D:\Face_Attendence\data\raw\user_002\000.jpg")

# %%
from recognition.embedder import FaceEmbedder
embedder = FaceEmbedder()
query_embedding = embedder.get_embedding(img)
# Out:
# d:\Face_Attendence\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# WARNING:tensorflow:From d:\Face_Attendence\venv\Lib\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
from recognition.matcher import FaceMatcher
FaceMatcher(query_embedding)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from src.recognition.matcher import FaceMatcher
#       2 FaceMatcher(query_embedding)
#
# ModuleNotFoundError: No module named 'src'

# %%
import timeit

TIMES = 10000

SETUP = """
symbols = '$¢£¥€¤'
def non_ascii(c):
    return c > 127
"""

def clock(label, cmd):
    res = timeit.repeat(cmd, setup=SETUP, number=TIMES)
    print(label, *(f'{x:.3f}' for x in res))

clock('listcomp        :', '[ord(s) for s in symbols if ord(s) > 127]')
clock('listcomp + func :', '[ord(s) for s in symbols if non_ascii(ord(s))]')
clock('filter + lambda :', 'list(filter(lambda c: c > 127, map(ord, symbols)))')
clock('filter + func   :', 'list(filter(non_ascii, map(ord, symbols)))')
# Out:
# listcomp        : 0.004 0.007 0.009 0.007 0.004
# listcomp + func : 0.008 0.009 0.005 0.006 0.006
# filter + lambda : 0.006 0.005 0.005 0.004 0.004
# filter + func   : 0.004 0.004 0.004 0.004 0.004
